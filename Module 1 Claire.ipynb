# %% [markdown]
# # Module_1: *(Claire)*
# - **Make sure to remove 'Template' from your final submission of this notebook.**
# ## Team Members:
# Faye Chiang
#
# Claire Meehan
#
# ## Project Title:
# *(Fill in)*

# %% [markdown]
# ## Project Goal:
# This project seeks to... *(what is the purpose of your project -- i.e., describe the question that you seek to answer by analyzing data.)*

# %% [markdown]
# ## Disease Background:
# - ***Please provide citations and/or hyperlinks to where you obtained information (including AI) for each of the bullet points.***
#
# *Fill in information about 11 bullets:*
# ### Faye:
# * Prevalence & incidence
# * Economic burden
# * Risk factors (genetic, lifestyle)
# * Societal determinants
# * Symptoms
# * Diagnosis
# ### Claire:
# * **Standard of care treatments (& reimbursement)**
#     * Anti-amyloid immunotherapy is used in early stages of Alzheimer's disease to target cognitive decline from amyloid plaques. Monoclonal antibodies like lecanemab and donanemab are examples that have been shown to slow Alzheimer's symptoms (Wu, 2025).
#     * Symptomatic relief for mild to severe Alzheimer's is typically provided by cholinesterase inhibitors and memantine which prevent the neurotransmitter acetylcholine from breaking down (Parsons, 2013). Increased acetylcholine helps relieve dementia effects because acetylcholine allows the patient to not forget short-term memories as often and helping the brain to better organize long-term memory (Mental Health America, n.d.).
# * **Disease progression & prognosis**
#     * According to Mayo Clinic (2025), the following is the progression and prognosis for Alzheimer's disease:
#     * Alzheimer's disease in the early stage is hard to diagnose. Biomarkers like amyloid plaques and tau tangles appear in brain scans, but symptoms are not yet noticed. This stage can last many years, but technology is evolving to help diagnose Alzheimer's earlier.
#     * Alzheimer's can cause mild cognitive impairment (MCI) which doesn't directly affect the patient's work or relationships, but affects their ability to recall things that they normally would be able to easily. Having MCI doesn't necessarily indicate that a person has Alzheimer's, but it can be a sign that can assist in an early diagnosis through checking for biomarkers.
#     * The diagnosis of Alzheimer's disease typically occurs during the mild dementia stage. This is when people close to the patient can begin to pick up on their dementia. People in this stage experience short-term memory loss, personality changes, trouble thinking clearly, and getting lost or losing items.
#     * Moderate dementia during Alzheimer's is when peopleforget even more and become more confused. They begin to need help with their everyday life, have poor judgment, and experience greater personality changes.
#     * Severe dementia occurs when the patient begins to lose their physical abilities, such as the ability to walk. The patient now needs assitance with their everyday life and may even lose the ability to communicate.
#     * People with Alzheimer's disease typically live for around 3 to 11 years after diagnosis.
# * **Continuum of care providers**
#     *
# * **Biological mechanisms (anatomy, organ physiology, cell & molecular physiology)**
#     *
# * **Clinical Trials/next-gen therapies**
#     *
#
#
# ### References
#
# Mayo Clinic. (2025, May 9). Alzheimer's stages: How the disease progresses. mayoclinic.org
#
# Mental Health America. (n.d.). What is acetylcholine? https://mhanational.org/resources/what-is-acetylcholine/
#
# Parsons, C. G., Danysz, W., Dekundy, A., & Pulte, I. (2013). Memantine and cholinesterase inhibitors: complementary mechanisms in the treatment of Alzheimer's disease. Neurotoxicity research, 24(3), 358–369. https://doi.org/10.1007/s12640-013-9398-z
#
# Wu, C. K., & Fuh, J. L. (2025). A 2025 update on treatment strategies for the Alzheimer's disease spectrum. Journal of the Chinese Medical Association : JCMA, 88(7), 495–502. https://doi.org/10.1097/JCMA.0000000000001252

# %% [markdown]
# ## Data-Set:
# *(Describe the data set(s) you will analyze. Cite the source(s) of the data. Describe how the data was collected -- What techniques were used? What units are the data measured in? Etc.)*

# %% [markdown]
# ## Data Analysis:
# *(Describe how you analyzed the data. This is where you should intersperse your Python code so that anyone reading this can run your code to perform the analysis that you did, generate your figures, etc.)*

# %% [markdown]
# ## Verify and validate your analysis:
# *(Describe how you checked to see that your analysis gave you an answer that you believe (verify). Describe how your determined if your analysis gave you an answer that is supported by other evidence (e.g., a published paper).*

# %% [markdown]
# ## Conclusions and Ethical Implications:
# *(Think about the answer your analysis generated, draw conclusions related to your overarching question, and discuss the ethical implications of your conclusions.*

# %% [markdown]
# ## Limitations and Future Work:
# *(Think about the answer your analysis generated, draw conclusions related to your overarching question, and discuss the ethical implications of your conclusions.*

# %% [markdown]
# ## AI Usage Statement:
# *This is where you will provide a short description on whether AI (and which AI) was used for any of the sections above and whether it helped or why it did not help.*
# - *Example statement: "We used Claude Code to generate our linear regression plot. At first, it did not include an R^2 calculation, so we added it to the code afterwards."*

# %% [markdown]
# ## GitHub Repository Link:
# *Please provide the link to your shared GitHub repository that includes this notebook and any other scripts, notebooks, or data that you used for this project.*

# %% [markdown]
# ## NOTES FROM YOUR TEAM:

# %% [markdown]
# ## QUESTIONS FOR YOUR TA:
# *These are questions we have for our TA.*
